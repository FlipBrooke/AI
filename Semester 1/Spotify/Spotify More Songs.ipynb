# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('spotify_songs.csv')

# %%
list(df.columns)
# Out:
# ['track_id',
#  'track_name',
#  'track_artist',
#  'track_popularity',
#  'track_album_id',
#  'track_album_name',
#  'track_album_release_date',
#  'playlist_name',
#  'playlist_id',
#  'playlist_genre',
#  'playlist_subgenre',
#  'danceability',
#  'energy',
#  'key',
#  'loudness',
#  'mode',
#  'speechiness',
#  'acousticness',
#  'instrumentalness',
#  'liveness',
#  'valence',
#  'tempo',
#  'duration_ms']

# %%
sns.histplot(data=df, x="track_popularity", bins=100,)
# Out:
# <AxesSubplot:xlabel='track_popularity', ylabel='Count'>

# %%
df['track_popularity'].quantile([0, 0.25, 0.5, 0.75, 1])
# Out:
# 0.00      0.0
# 0.25     24.0
# 0.50     45.0
# 0.75     62.0
# 1.00    100.0
# Name: track_popularity, dtype: float64

# %% [markdown]
# ## Track Popularity
# The average popularity is 42.47, although 2703 songs have a popularity of 0.

# %%
def avg(data):
    return(df[data].mean())

def standef(data):
    return(df[data].std())

# %%
print(avg('danceability'))
print(standef('danceability'))
# Out:
# 0.6548495202996926
# 0.14508532044765107

# %%
0.6548495202996926+0.14508532044765107
# Out:
# 0.7999348407473437

# %%
0.6548495202996926-0.14508532044765107
# Out:
# 0.5097641998520415

# %%
sns.histplot(data=df, x="danceability", bins=100,)
# Out:
# <AxesSubplot:xlabel='danceability', ylabel='Count'>

# %% [markdown]
# ## Data Analysis
# ### How Impressive is Dance Monkey earning a score of 100?
# Extremely impressive, It's the only song in the dataset with a score of 100
# ### What is the standard distrubution of popularity
# 24.98
# ### Is rap or pop more speechy?
# Rap tends to be a lot more speechy than pop is. Pop often has no speach, while all rap has at least a little speech

# %%
print(df["track_popularity"].std())
# Out:
# 24.984074486186543

# %%
filtered_data = df[df['playlist_genre'].isin(['pop', 'rap'])]
sns.histplot(data=filtered_data, x='speechiness', hue='playlist_genre', bins=30, alpha=0.5, multiple='layer')
# Out:
# <AxesSubplot:xlabel='speechiness', ylabel='Count'>

# %% [markdown]
# # Choose a Data Set
# Pick one of the following data sets to analyze for your final project.
# - [Cosmetics](https://drive.google.com/drive/folders/1qvmRfGb7a_pYAtgW6614gxlP-bxl_Ptz?usp=drive_link)
# - [Mental Health](https://drive.google.com/drive/folders/1YOp1aQVcmqlAkUEGHNPl_TyNXbY-xHwO?usp=drive_link)
# - [Pokemon](https://drive.google.com/drive/folders/1kDu2oRgm_hUW5hdM0tHnMUqCGSKUYT1v?usp=drive_link)
# - [Ramen](https://drive.google.com/drive/folders/1Y4_5QHOCy8rHc5EsEwDUuoCfp2WLo-MN?usp=drive_link)
# - [Student Performance](https://drive.google.com/drive/folders/1fE31Ka38AnGpgfI_Es3z4psuA0phhH0Y?usp=drive_link)

# %% [markdown]
# # What types are most commonly together?

# %% [markdown]
# Which two Pokemon types are most commonly found together in dual type pokemon (Pokemon with more than a single type)

# %% [markdown]
# # My Analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('pokemon.csv')
dual_type_pokemon = df[df['Type 2'].notna()]
type_combinations = dual_type_pokemon[['Type 1', 'Type 2']].copy()
type_combinations['Combination'] = type_combinations.apply(lambda x: tuple(sorted([x['Type 1'], x['Type 2']])), axis=1)

type_counts = type_combinations['Combination'].value_counts()

print(type_counts)

type_counts.head(10).plot(kind='barh', figsize=(10, 7))
plt.xlabel('Count')
plt.ylabel('Type Combination')
plt.title('Top 10 Most Frequent Dual-Type Pokémon')
plt.show()

print(f"Mean: {type_counts.mean()}")
# Out:
# Combination
# (Flying, Normal)    24
# (Grass, Poison)     15
# (Bug, Flying)       14
# (Bug, Poison)       13
# (Ground, Water)     10
#                     ..
# (Fire, Rock)         1
# (Flying, Steel)      1
# (Bug, Ghost)         1
# (Bug, Water)         1
# (Fire, Water)        1
# Name: count, Length: 115, dtype: int64
# Mean: 3.6

# %% [markdown]
# # My Answer

# %% [markdown]
# Flying and normal are most commonly found together, and appear 24 times. This makes sense as normal's often assigned to real world animals, and pokemon has a lot of real world birds. Grass/Poison also makes sense, as Bulbasaur is the only dual type gen 1 starter, and they have this exact typing. The average combo is used by 3.6 pokemon.
